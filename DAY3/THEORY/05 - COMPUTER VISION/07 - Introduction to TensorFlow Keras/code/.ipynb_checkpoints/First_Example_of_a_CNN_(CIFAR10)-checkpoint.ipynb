# %% [markdown]
# <a href="https://colab.research.google.com/github/michelucci/oreilly-london-ai/blob/master/day1/First_Example_of_a_CNN_(CIFAR10).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # First example of a CNN
#
# (C) Umberto Michelucci
#
# umberto.michelucci@toelt.ai
#
# www.toelt.ai

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten

#from tensorflow import keras
import tensorflow.keras.backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback

from tensorflow.keras.datasets import cifar10
import numpy as np
from tensorflow.keras import utils

import matplotlib.pyplot as plt

# %%
import matplotlib as mpl
mpl.style.use('classic')

# %% [markdown]
# ## Model

# %%
def createModel():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.4))
 
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.4))
 
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.4))
 
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nClasses, activation='softmax'))
     
    return model

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# %%
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train,axis=(0,1,2,3))
x_train = (x_train-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)

# %%
nClasses = 10
y_train = utils.to_categorical(y_train,nClasses)
y_test = utils.to_categorical(y_test,nClasses)

# %%
x_train.shape[1:]
# Out:
# (32, 32, 3)

# %%
def createModel():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=x_train.shape[1:]))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
 
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
 
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
 
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nClasses, activation='softmax'))
     
    return model

# %%
K.clear_session()
model = createModel()
# Out:
# 2022-04-05 17:25:40.475998: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
AdamOpt = Adam(learning_rate=0.001)
model.compile(optimizer=AdamOpt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 10)

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (10000, 32, 32, 3)
# (10000, 10)

# %%
plt.imshow(x_train[4])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
batch_size = 256
epochs = 10

history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, 
                   validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 196/196 [==============================] - 42s 213ms/step - loss: 0.8557 - accuracy: 0.6971 - val_loss: 0.7805 - val_accuracy: 0.7272
# Epoch 2/10
# 196/196 [==============================] - 43s 218ms/step - loss: 0.7912 - accuracy: 0.7229 - val_loss: 0.7302 - val_accuracy: 0.7456
# Epoch 3/10
# 196/196 [==============================] - 44s 226ms/step - loss: 0.7544 - accuracy: 0.7369 - val_loss: 0.7208 - val_accuracy: 0.7513
# Epoch 4/10
# 196/196 [==============================] - 44s 225ms/step - loss: 0.7229 - accuracy: 0.7484 - val_loss: 0.6813 - val_accuracy: 0.7674
# Epoch 5/10
# 196/196 [==============================] - 47s 240ms/step - loss: 0.6925 - accuracy: 0.7572 - val_loss: 0.6851 - val_accuracy: 0.7684
# Epoch 6/10
# 196/196 [==============================] - 46s 233ms/step - loss: 0.6576 - accuracy: 0.7711 - val_loss: 0.6499 - val_accuracy: 0.7777
# Epoch 7/10
# 196/196 [==============================] - 46s 235ms/step - loss: 0.6495 - accuracy: 0.7738 - val_loss: 0.6408 - val_accuracy: 0.7801
# Epoch 8/10
# 196/196 [==============================] - 49s 251ms/step - loss: 0.6179 - accuracy: 0.7854 - val_loss: 0.6266 - val_accuracy: 0.7876
# Epoch 9/10
# 196/196 [==============================] - 52s 267ms/step - loss: 0.6087 - accuracy: 0.7877 - val_loss: 0.6296 - val_accuracy: 0.7830
# Epoch 10/10
# 196/196 [==============================] - 57s 291ms/step - loss: 0.5982 - accuracy: 0.7904 - val_loss: 0.5992 - val_accuracy: 0.7928

# %%
history.history
# Out:
# {'loss': [0.8557260036468506,
#   0.7912258505821228,
#   0.7543981075286865,
#   0.7228586673736572,
#   0.6925185322761536,
#   0.6575875878334045,
#   0.6494576334953308,
#   0.6178989410400391,
#   0.608729362487793,
#   0.598210871219635],
#  'accuracy': [0.6970800161361694,
#   0.7228999733924866,
#   0.7368999719619751,
#   0.7483999729156494,
#   0.7571799755096436,
#   0.7710999846458435,
#   0.7737600207328796,
#   0.7854400277137756,
#   0.7876799702644348,
#   0.7904199957847595],
#  'val_loss': [0.7804659008979797,
#   0.7301870584487915,
#   0.7207731604576111,
#   0.681309700012207,
#   0.6851179003715515,
#   0.6498753428459167,
#   0.6407931447029114,
#   0.6266452670097351,
#   0.6296366453170776,
#   0.5991692543029785],
#  'val_accuracy': [0.7271999716758728,
#   0.7455999851226807,
#   0.7512999773025513,
#   0.7674000263214111,
#   0.7684000134468079,
#   0.7777000069618225,
#   0.7800999879837036,
#   0.7875999808311462,
#   0.7829999923706055,
#   0.7928000092506409]}

# %%
# Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'black',linewidth=3.0)
plt.plot(history.history['val_loss'],'black',ls = '--', linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
#plt.title('Loss Curves',fontsize=16)
# Out:
# Text(0, 0.5, 'Loss')

# %%
# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'black',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'black',ls = '--',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18, 
           loc = 'lower right')
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
#plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0, 0.5, 'Accuracy')
